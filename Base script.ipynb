# %%
# Part of script for loading, filtering and reorganising data - using Nominatim

import pandas as pd
import folium
from geopy.geocoders import Nominatim

# Read the data from your mineral collection file
CollectionData_CzechRepublic = pd.read_excel("Raw data Tsjechie collectie.xlsx")

# Replacing empty locations with '-'
for index, row in CollectionData_CzechRepublic.iterrows():
    if pd.notna(row['Land']) == False :
        CollectionData_CzechRepublic.loc[index, 'Land'] = '-' 
    if pd.notna(row['COUNTRY']) == False :
        CollectionData_CzechRepublic.loc[index, 'COUNTRY'] = '-' 
    if pd.notna(row['Regio']) == False :
        CollectionData_CzechRepublic.loc[index, 'Regio'] = '-' 
    if pd.notna(row['District']) == False :
        CollectionData_CzechRepublic.loc[index, 'District'] = '-' 
    if pd.notna(row['Locatie']) == False :
        CollectionData_CzechRepublic.loc[index, 'Locatie'] = '-' 
    if pd.notna(row['LOCALITYTEXT']) == False :
        CollectionData_CzechRepublic.loc[index, 'LOCALITYTEXT'] = '-' 
    if pd.notna(row['LOCALITY']) == False :
        CollectionData_CzechRepublic.loc[index, 'LOCALITY'] = '-' 

# Removing empty rows
indices_to_drop = []
for index, row in CollectionData_CzechRepublic.iterrows():
    if pd.isna(row['REGISTRATIONNUMBER']):
        indices_to_drop.append(index)
CollectionData_CzechRepublic = CollectionData_CzechRepublic.drop(indices_to_drop)


#print(CollectionData_CzechRepublic[["REGISTRATIONNUMBER", "Coordinaten", "Land", "Regio", "District", 'LOCALITYTEXT', 'LOCALITY']])


# Initialize geocoder
geolocator = Nominatim(user_agent="mineral_geocoder")

#make new dataframe with complete information
CollectionData_CzechRepublic_Reorganised = pd.DataFrame(columns=['RegistrationNumber','Description','Coordinates','Location','Accuracy'])        

Czechoslovakia = geolocator.geocode("Nederland, Utrecht, Amersfoort")

for index, row in CollectionData_CzechRepublic.iterrows():
    
    if index>200: break
    else:
              
        if pd.notna(row['Coordinaten']) and '°' not in row['Coordinaten'] and ',' in row['Coordinaten']:
            # If coordinates are available, and they are given as float, plot the marker at the exact coordinates
            coordinates = [float(coord) for coord in row['Coordinaten'].split(',')]
            location = geolocator.geocode(row['Coordinaten'])
            accuracy = 0
            print('Row', index+2, ': coordinates provided. Location:', location)
        elif pd.notna(row['Coordinaten']) and geolocator.geocode(row['Coordinaten']):
            # If coordinates are available, but are given as tring, geocode coordinates and plot the marker at the exact coordinates
            location = geolocator.geocode(row['Coordinaten'])
            coordinates = [location.latitude, location.longitude]
            accuracy = 1
            print('Row', index+2, ': coordinates provided as string: "', row['Coordinaten'], '". Location:', location)
        elif geolocator.geocode(f"{row['Land']}, {row['Regio']}, {row['District']}, {row['Locatie']}"):
            # If coordinates are not available, geocode the location
            location = geolocator.geocode(f"{row['Land']}, {row['Regio']}, {row['District']}, {row['Locatie']}")
            coordinates = [location.latitude, location.longitude]
            accuracy = 2
            print('Row', index+2, ': geocode attempt 1: Land, Regio, District, Locatie. \n    Location provided:',f"{row['Land']}, {row['Regio']}, {row['District']}, {row['Locatie']}" ,'\n    Location calculated:', location)
        elif geolocator.geocode(f"{row['Land']}, {row['Regio']}, {row['District']}, -"):
            # If geocode does not work, try different data combination 1: District
            location = geolocator.geocode(f"{row['Land']}, {row['Regio']}, {row['District']}, -")
            coordinates = [location.latitude, location.longitude]
            accuracy = 3
            print('Row', index+2, ': geocode attempt 2: Land, Regio, District. \n    Location provided:',f"{row['Land']}, {row['Regio']}, {row['District']}" ,'\n    Location calculated:', location)
        elif geolocator.geocode(f"{row['Land']}, {row['Regio']}, -, -"):
            # If geocode does not work, try different data combination 2: Region
            location = geolocator.geocode(f"{row['Land']}, {row['Regio']}, -, -")
            coordinates = [location.latitude, location.longitude]
            accuracy = 4
            print('Row', index+2, ': geocode attempt 3: Land, Regio. \n    Location provided:',f"{row['Land']}, {row['Regio']}" ,'\n    Location calculated:', location)
        elif geolocator.geocode(f"{row['LOCALITYTEXT']}"):
            # If geocode does not work, try different data combination 3: LOCALITYTEXT
            location = geolocator.geocode(f"{row['LOCALITYTEXT']}")
            coordinates = [location.latitude, location.longitude]
            accuracy = 5
            print('Row', index+2, ': geocode attempt 4: LOCALITYTEXT. \n    Location provided:',f"{row['LOCALITYTEXT']}" ,'\n    Location calculated:', location)
        elif geolocator.geocode(f"{row['LOCALITY']}"): 
            # If geocode does not work, try different data combination 4: LOCALITY
            location = geolocator.geocode(f"{row['LOCALITY']}")
            coordinates = [location.latitude, location.longitude]
            accuracy = 6
            print('Row', index+2, ': geocode attempt 5: LOCALITY. \n    Location provided:',f"{row['LOCALITY']}" ,'\n    Location calculated:', location)
        elif geolocator.geocode(f"{row['Land']}, -, -, -"):
            # If geocode does not work, try different data combination 5: Land
            location = geolocator.geocode(f"{row['Land']}, -, -, -")
            coordinates = [location.latitude, location.longitude]
            accuracy = 7
            print('Row', index+2, ': geocode attempt 6: Land. \n    Location provided:',f"{row['COUNTRY']}" ,'\n    Location calculated:', location)
        elif row['COUNTRY'] == "Czechoslovakia":
            # If geocode does not work, and Country = Czeckoslovakia
            location = 'Czechoslovakia'
            coordinates = [49.115334, 18.109488]
            accuracy = 8
            print('Row', index+2, ': geocode attempt 7 unsuccessful: Country = "Czechoslovakia". \n    Location provided:',f"{row['COUNTRY']}" ,'\n    Location calculated:', location)
        elif row['COUNTRY'] == "Unknown":
            # If geocode does not work, and Country = Unknown
            location = 'Unknown'
            coordinates = []
            accuracy = 9
            print('Row', index+2, ': geocode attempt 7 unsuccessful: Country = "Unknown". \n    Location provided:',f"{row['COUNTRY']}" ,'\n    Location calculated:', location)
        elif geolocator.geocode(f"{row['COUNTRY']}, {row['Regio']}, {row['District']}, {row['Locatie']}"):
            # If geocode does not work and Country != Chechoslovakia or unknown, try different data combination 6: Country
            location = geolocator.geocode(f"{row['COUNTRY']}, {row['Regio']}, {row['District']}, {row['Locatie']}")
            coordinates = [location.latitude, location.longitude]
            accuracy = 10
            print('Row', index+2, ': geocode attempt 7: Country. \n    Location provided:',f"{row['COUNTRY']}" ,'\n    Location calculated:', location)
        else:
            # If last geocode option fails, enter location = unknown
            location = 'Unknown'
            coordinates = []
            accuracy = 11
            print('Row', index+2, ': geocode unsuccessful. \n    Location provided:',f"{row['COUNTRY']}, {row['Regio']}, {row['District']}, {row['Locatie']}, {row['LOCALITYTEXT']}, {row['LOCALITY']}" ,'\n    Location calculated:', location)
        
        #checking certain accuracies
        if location == 'Česko':
            CollectionData_CzechRepublic_Reorganised.loc[index]['Accuracy'] = 12
        
        # Saving data in reorganised dataframe 
        CollectionData_CzechRepublic_Reorganised.loc[index] = {'RegistrationNumber':row['REGISTRATIONNUMBER'],'Description':row['FULLSCIENTIFICNAME'],'Coordinates':coordinates,'Location':location, 'Accuracy':accuracy}
# Out:
# Row 2 : coordinates provided. Location: 402, Stonařov, okres Jihlava, Kraj Vysočina, 588 33, Česko
# Row 3 : geocode attempt 7 unsuccessful: Country = "Czechoslovakia".
#     Location provided: Czechoslovakia
#     Location calculated: Czechoslovakia
# Row 4 : geocode attempt 3: Land, Regio.
#     Location provided: Czech Republic, Central Bohemian
#     Location calculated: Středočeské muzeum v Roztokách u Prahy, 1, Zámek, Roztoky u Prahy, Roztoky, okres Praha-západ, Střední Čechy, 252 63, Česko
# Row 5 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Bílina
#     Location calculated: Bílina, okres Teplice, Ústecký kraj, Česko
# Row 6 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 7 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Cínovec
#     Location calculated: Cínovec, Dubí, okres Teplice, Ústecký kraj, Česko
# Row 8 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Olomouc, Šumperk, Sobotín
#     Location calculated: Sobotín, okres Šumperk, Olomoucký kraj, Střední Morava, 788 16, Česko
# Row 9 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Děčín, Těchlovice
#     Location calculated: Těchlovice, okres Děčín, Ústecký kraj, Severozápad, Česko
# Row 10 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Ústí nad Labem, Povrly
#     Location calculated: Povrly, okres Ústí nad Labem, Ústecký kraj, Severozápad, 403 32, Česko
# Row 11 : geocode attempt 3: Land, Regio.
#     Location provided: Czech Republic, Central Bohemian
#     Location calculated: Středočeské muzeum v Roztokách u Prahy, 1, Zámek, Roztoky u Prahy, Roztoky, okres Praha-západ, Střední Čechy, 252 63, Česko
# Row 12 : coordinates provided. Location: Chebská křižovatka, Máchova, Třešňovka, Mariánské Lázně, okres Cheb, Karlovarský kraj, Severozápad, 353 43, Česko
# Row 13 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Bílina
#     Location calculated: Bílina, okres Teplice, Ústecký kraj, Česko
# Row 14 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, -, -, -
#     Location calculated: Česko
# Row 15 : geocode attempt 7: Country.
#     Location provided: Czech Republic
#     Location calculated: Česko
# Row 16 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, -, -, -
#     Location calculated: Česko
# Row 17 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, -, -, -
#     Location calculated: Česko
# Row 18 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, -, -, -
#     Location calculated: Česko
# Row 19 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Bílina
#     Location calculated: Bílina, okres Teplice, Ústecký kraj, Česko
# Row 20 : coordinates provided. Location: 19812, Hlineč, Jesínky, Bochov, okres Karlovy Vary, Karlovarský kraj, Severozápad, Česko
# Row 21 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Homole u Panny, -
#     Location calculated: Homole u Panny, okres Ústí nad Labem, Ústecký kraj, Česko
# Row 22 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, -, -, -
#     Location calculated: Česko
# Row 23 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Ústí nad Labem, Roztoky
#     Location calculated: Roztoky nad Labem, Povrly, okres Ústí nad Labem, Ústecký kraj, Severozápad, Česko
# Row 24 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, -, -
#     Location calculated: Ústí nad Labem, okres Ústí nad Labem, Ústecký kraj, Česko
# Row 25 : geocode attempt 3: Land, Regio.
#     Location provided: Czech Republic, Central Bohemian
#     Location calculated: Středočeské muzeum v Roztokách u Prahy, 1, Zámek, Roztoky u Prahy, Roztoky, okres Praha-západ, Střední Čechy, 252 63, Česko
# Row 26 : geocode attempt 3: Land, Regio.
#     Location provided: Czech Republic, Central Bohemian
#     Location calculated: Středočeské muzeum v Roztokách u Prahy, 1, Zámek, Roztoky u Prahy, Roztoky, okres Praha-západ, Střední Čechy, 252 63, Česko
# Row 27 : geocode attempt 3: Land, Regio.
#     Location provided: Czech Republic, Central Bohemian
#     Location calculated: Středočeské muzeum v Roztokách u Prahy, 1, Zámek, Roztoky u Prahy, Roztoky, okres Praha-západ, Střední Čechy, 252 63, Česko
# Row 28 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Bílina
#     Location calculated: Bílina, okres Teplice, Ústecký kraj, Česko
# Row 29 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Olomouc, Šumperk, Sobotín
#     Location calculated: Sobotín, okres Šumperk, Olomoucký kraj, Střední Morava, 788 16, Česko
# Row 30 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Měrunice
#     Location calculated: Měrunice, okres Teplice, Ústecký kraj, Česko
# Row 31 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Duchcov
#     Location calculated: Duchcov, okres Teplice, Ústecký kraj, 419 01, Česko
# Row 32 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Duchcov
#     Location calculated: Duchcov, okres Teplice, Ústecký kraj, 419 01, Česko
# Row 33 : geocode attempt 6: Land.
#     Location provided: Czechoslovakia
#     Location calculated: Česko
# Row 34 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Duchcov
#     Location calculated: Duchcov, okres Teplice, Ústecký kraj, 419 01, Česko
# Row 35 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, -, -, -
#     Location calculated: Česko
# Row 36 : geocode attempt 7 unsuccessful: Country = "Unknown".
#     Location provided: Unknown
#     Location calculated: Unknown
# Row 37 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Cheb, Hazlov
#     Location calculated: Hazlov, okres Cheb, Karlovarský kraj, Severozápad, 351 32, Česko
# Row 38 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Krásno
#     Location calculated: Krásno, okres Sokolov, Karlovarský kraj, Severozápad, Česko
# Row 39 : geocode attempt 3: Land, Regio.
#     Location provided: Czech Republic, Central Bohemian
#     Location calculated: Středočeské muzeum v Roztokách u Prahy, 1, Zámek, Roztoky u Prahy, Roztoky, okres Praha-západ, Střední Čechy, 252 63, Česko
# Row 40 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Krásno
#     Location calculated: Krásno, okres Sokolov, Karlovarský kraj, Severozápad, Česko
# Row 41 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Olomouc, Jeseník, Žulová
#     Location calculated: Žulová, okres Jeseník, Olomoucký kraj, Střední Morava, Česko
# Row 42 : coordinates provided. Location: Rejhotice, Loučná nad Desnou, okres Šumperk, Olomoucký kraj, Střední Morava, Česko
# Row 43 : coordinates provided. Location: Rejhotice, Loučná nad Desnou, okres Šumperk, Olomoucký kraj, Střední Morava, Česko
# Row 44 : geocode attempt 5: LOCALITY.
#     Location provided: Pisek
#     Location calculated: Písek, okres Písek, Jihozápad, Česko
# Row 45 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Cínovec
#     Location calculated: Cínovec, Dubí, okres Teplice, Ústecký kraj, Česko
# Row 46 : geocode attempt 3: Land, Regio.
#     Location provided: Czech Republic, Central Bohemian
#     Location calculated: Středočeské muzeum v Roztokách u Prahy, 1, Zámek, Roztoky u Prahy, Roztoky, okres Praha-západ, Střední Čechy, 252 63, Česko
# Row 47 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Krásno
#     Location calculated: Krásno, okres Sokolov, Karlovarský kraj, Severozápad, Česko
# Row 48 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Krásno
#     Location calculated: Krásno, okres Sokolov, Karlovarský kraj, Severozápad, Česko
# Row 49 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Krásno
#     Location calculated: Krásno, okres Sokolov, Karlovarský kraj, Severozápad, Česko
# Row 50 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Liberec, Semily, Košťálov
#     Location calculated: Košťálov, okres Semily, Liberecký kraj, Severovýchod, 512 02, Česko
# Row 51 : geocode attempt 3: Land, Regio.
#     Location provided: Czech Republic, Moravian-Silesian
#     Location calculated: Moravskoslezské inovační centrum Ostrava, a.s., Pustkovec, Ostrava, okres Ostrava-město, Moravskoslezský kraj, Moravskoslezsko, Česko
# Row 52 : coordinates provided. Location: Rejhotice, Loučná nad Desnou, okres Šumperk, Olomoucký kraj, Střední Morava, Česko
# Row 53 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Cínovec
#     Location calculated: Cínovec, Dubí, okres Teplice, Ústecký kraj, Česko
# Row 54 : coordinates provided. Location: 8, Bořislav, okres Teplice, Ústecký kraj, 411 31, Česko
# Row 55 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Vysočina, Žďár nad Sázavou, Dolní Bory
#     Location calculated: Dolní Bory, Bory, okres Žďár nad Sázavou, Kraj Vysočina, 594 61, Česko
# Row 56 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Vysočina, Žďár nad Sázavou, Heřmanov
#     Location calculated: Heřmanov, okres Žďár nad Sázavou, Kraj Vysočina, 594 58, Česko
# Row 57 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Vysočina, Žďár nad Sázavou, Heřmanov
#     Location calculated: Heřmanov, okres Žďár nad Sázavou, Kraj Vysočina, 594 58, Česko
# Row 58 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, -, -
#     Location calculated: Karlovy Vary, okres Karlovy Vary, Karlovarský kraj, Severozápad, Česko
# Row 59 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Bílina
#     Location calculated: Bílina, okres Teplice, Ústecký kraj, Česko
# Row 60 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Želénky
#     Location calculated: Želénky, Všechlapy, Zabrušany, okres Teplice, Ústecký kraj, Česko
# Row 61 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Karlovy Vary, Černava
#     Location calculated: Černava, okres Karlovy Vary, Karlovarský kraj, Severozápad, Česko
# Row 62 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, -, -
#     Location calculated: Karlovy Vary, okres Karlovy Vary, Karlovarský kraj, Severozápad, Česko
# Row 63 : coordinates provided. Location: VII.a/14/C, U Červené lávky, Stříbro, okres Tachov, Plzeňský kraj, Jihozápad, 349 01, Česko
# Row 64 : geocode attempt 3: Land, Regio.
#     Location provided: Czech Republic, Central Bohemian
#     Location calculated: Středočeské muzeum v Roztokách u Prahy, 1, Zámek, Roztoky u Prahy, Roztoky, okres Praha-západ, Střední Čechy, 252 63, Česko
# Row 65 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, -, -
#     Location calculated: Karlovy Vary, okres Karlovy Vary, Karlovarský kraj, Severozápad, Česko
# Row 66 : coordinates provided. Location: PR Číčov, 15, Hořenec, Libčeves, okres Louny, Ústecký kraj, 439 26, Česko
# Row 67 : coordinates provided. Location: PR Číčov, 15, Hořenec, Libčeves, okres Louny, Ústecký kraj, 439 26, Česko
# Row 68 : coordinates provided. Location: PR Číčov, 15, Hořenec, Libčeves, okres Louny, Ústecký kraj, 439 26, Česko
# Row 69 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Bílina
#     Location calculated: Bílina, okres Teplice, Ústecký kraj, Česko
# Row 70 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Bílina
#     Location calculated: Bílina, okres Teplice, Ústecký kraj, Česko
# Row 71 : coordinates provided. Location: VII.a/14/C, U Červené lávky, Stříbro, okres Tachov, Plzeňský kraj, Jihozápad, 349 01, Česko
# Row 72 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, -
#     Location calculated: Teplice, okres Teplice, Ústecký kraj, Severozápad, Česko
# Row 73 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Chomutov, Loučná pod Klínovcem
#     Location calculated: Loučná pod Klínovcem, okres Chomutov, Ústecký kraj, Severozápad, Česko
# Row 74 : geocode attempt 6: Land.
#     Location provided: Czechoslovakia
#     Location calculated: Česko
# Row 75 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Bořislav
#     Location calculated: Bořislav, okres Teplice, Ústecký kraj, Česko
# Row 76 : geocode attempt 6: Land.
#     Location provided: Czechoslovakia
#     Location calculated: Česko
# Row 77 : coordinates provided. Location: Jedová (Dědova) hora, 11715, Neřežín, Chaloupky, okres Beroun, Střední Čechy, 267 62, Česko
# Row 78 : geocode attempt 3: Land, Regio.
#     Location provided: Czech Republic, Central Bohemian
#     Location calculated: Středočeské muzeum v Roztokách u Prahy, 1, Zámek, Roztoky u Prahy, Roztoky, okres Praha-západ, Střední Čechy, 252 63, Česko
# Row 79 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Karlovy Vary, -
#     Location calculated: Karlovy Vary, Nákladní, Rybáře, Karlovy Vary, okres Karlovy Vary, Karlovarský kraj, Severozápad, 360 10, Česko
# Row 80 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Osek
#     Location calculated: Osek, okres Teplice, Ústecký kraj, 417 05, Česko
# Row 81 : geocode attempt 7 unsuccessful: Country = "Czechoslovakia".
#     Location provided: Czechoslovakia
#     Location calculated: Czechoslovakia
# Row 82 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Cheb, Aš
#     Location calculated: Aš, okres Cheb, Karlovarský kraj, Severozápad, 352 01, Česko
# Row 83 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Ústí nad Labem, -, Velké Březno
#     Location calculated: RoBiN OIL Velké Březno, 25845, Valtířov nad Labem, Velké Březno, okres Ústí nad Labem, Ústecký kraj, 403 23, Česko
# Row 84 : coordinates provided. Location: Chebská křižovatka, Máchova, Třešňovka, Mariánské Lázně, okres Cheb, Karlovarský kraj, Severozápad, 353 43, Česko
# Row 85 : geocode attempt 3: Land, Regio.
#     Location provided: Czech Republic, Central Bohemian
#     Location calculated: Středočeské muzeum v Roztokách u Prahy, 1, Zámek, Roztoky u Prahy, Roztoky, okres Praha-západ, Střední Čechy, 252 63, Česko
# Row 86 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 87 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 88 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 89 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 90 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 91 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 92 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 93 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 94 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 95 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 96 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 97 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 98 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 99 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 100 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 101 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 102 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 103 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 104 : coordinates provided. Location: 840, Lánský dvůr, Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 105 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 106 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 107 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 108 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 109 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 110 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 111 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 112 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 113 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 114 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 115 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 116 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 117 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 118 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 119 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 120 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 121 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 122 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 123 : coordinates provided. Location: 840, Lánský dvůr, Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 124 : coordinates provided. Location: 840, Lánský dvůr, Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 125 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 126 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 127 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 128 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 129 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 130 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 131 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 132 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 133 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 134 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 135 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 136 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 137 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 138 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 139 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 140 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 141 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 142 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 143 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 144 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 145 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 146 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 147 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 148 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 149 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 150 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 151 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 152 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 153 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 154 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 155 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 156 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 157 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 158 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 159 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 160 : coordinates provided. Location: 840, Lánský dvůr, Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 161 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 162 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 163 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 164 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 165 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 166 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 167 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 168 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 169 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 170 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 171 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 172 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 173 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 174 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 175 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 176 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 177 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 178 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 179 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 180 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 181 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 182 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 183 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 184 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 185 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 186 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 187 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 188 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 189 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 190 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 191 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: Horní Slavkov, okres Sokolov, Karlovarský kraj, Severozápad, 357 31, Česko
# Row 192 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, okres Karlovy Vary, Karlovarský kraj, Severozápad, 362 51, Česko
# Row 193 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, okres Karlovy Vary, Karlovarský kraj, Severozápad, 362 51, Česko
# Row 194 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, okres Karlovy Vary, Karlovarský kraj, Severozápad, 362 51, Česko
# Row 195 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, okres Karlovy Vary, Karlovarský kraj, Severozápad, 362 51, Česko
# Row 196 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, okres Karlovy Vary, Karlovarský kraj, Severozápad, 362 51, Česko
# Row 197 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, okres Karlovy Vary, Karlovarský kraj, Severozápad, 362 51, Česko
# Row 198 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, okres Karlovy Vary, Karlovarský kraj, Severozápad, 362 51, Česko
# Row 199 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, okres Karlovy Vary, Karlovarský kraj, Severozápad, 362 51, Česko
# Row 200 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, okres Karlovy Vary, Karlovarský kraj, Severozápad, 362 51, Česko
# Row 201 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, okres Karlovy Vary, Karlovarský kraj, Severozápad, 362 51, Česko
# Row 202 : geocode attempt 1: Land, Regio, District, Locatie.
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, okres Karlovy Vary, Karlovarský kraj, Severozápad, 362 51, Česko

# %%
# Part of script for loading, filtering and reorganising data - Using Google
# Limiet API: For validating adress: 6,000 QPM

import pandas as pd
import folium
from folium.plugins import MarkerCluster
from geopy.geocoders import Nominatim
from geopy.geocoders import GoogleV3
import time

# Read the data from your mineral collection file
CollectionData_CzechRepublic = pd.read_excel("Raw data Tsjechie collectie.xlsx")

# Replacing empty locations with '-'
for index, row in CollectionData_CzechRepublic.iterrows():
    if pd.notna(row['Land']) == False :
        CollectionData_CzechRepublic.loc[index, 'Land'] = '-' 
    if pd.notna(row['COUNTRY']) == False :
        CollectionData_CzechRepublic.loc[index, 'COUNTRY'] = '-' 
    if pd.notna(row['Regio']) == False :
        CollectionData_CzechRepublic.loc[index, 'Regio'] = '-' 
    if pd.notna(row['District']) == False :
        CollectionData_CzechRepublic.loc[index, 'District'] = '-' 
    if pd.notna(row['Locatie']) == False :
        CollectionData_CzechRepublic.loc[index, 'Locatie'] = '-' 
    if pd.notna(row['LOCALITYTEXT']) == False :
        CollectionData_CzechRepublic.loc[index, 'LOCALITYTEXT'] = '-' 
    if pd.notna(row['LOCALITY']) == False :
        CollectionData_CzechRepublic.loc[index, 'LOCALITY'] = '-' 

# Removing empty rows
indices_to_drop = []
for index, row in CollectionData_CzechRepublic.iterrows():
    if pd.isna(row['REGISTRATIONNUMBER']):
        indices_to_drop.append(index)
CollectionData_CzechRepublic = CollectionData_CzechRepublic.drop(indices_to_drop)


#print(CollectionData_CzechRepublic[["REGISTRATIONNUMBER", "Coordinaten", "Land", "Regio", "District", 'LOCALITYTEXT', 'LOCALITY']])

# Load shapefile or GeoJSON file containing boundary information
Borders_CzechRepublic_level_0 = gpd.read_file("GeoJSON files\GADM.org Czech Repubic\level-0.txt")
Borders_CzechRepublic_level_1 = gpd.read_file("GeoJSON files\GADM.org Czech Repubic\gadm41_CZE_1.json\gadm41_CZE_1.JSON")
Borders_CzechRepublic_level_2 = gpd.read_file("GeoJSON files\GADM.org Czech Repubic\gadm41_CZE_2.json\gadm41_CZE_2.JSON")
#print(Borders_CzechRepublic_level_2)

# Initialize geocoder
geolocator = GoogleV3(api_key="AIzaSyDqMCJoNkUg2z1grFWHzD5jzd87W_OySK8")
geolocator2 = Nominatim(user_agent="mineral_geocoder")

#make new dataframe with complete information
CollectionData_CzechRepublic_Reorganised = pd.DataFrame(columns=['RegistrationNumber','Description','Coordinates','Location','Accuracy'])        

Czechoslovakia = geolocator.geocode("Nederland, Utrecht, Amersfoort")

start_time = time.time()
Q = 0
for index, row in CollectionData_CzechRepublic.iterrows():
    
    if index>2000: break
    elif Q>0:
        dt=time.time() - start_time
        dQdt=Q/(dt/60)
        if dQdt>6000: 
            print('Δt = ', dt, '\nΔQ = ', Q, '\ndQ/dt = ', dQdt)
            time.sleep(dt)
        start_time = time.time()
        Q=0
    else:
              
        if pd.notna(row['Coordinaten']):
            if '°' not in row['Coordinaten'] and ',' in row['Coordinaten']:
                # If coordinates are available, and they are given as float, plot the marker at the exact coordinates
                coordinates = [float(coord) for coord in row['Coordinaten'].split(',')]
                location = geolocator.geocode(row['Coordinaten'])
                accuracy = 0
                print('Row', index+2, ': coordinates provided. Location:', location)
                Q += 1
            elif pd.notna(row['Coordinaten']) and (location := geolocator2.geocode(row['Coordinaten'])):
                # If coordinates are available, but are given as tring, geocode coordinates and plot the marker at the exact coordinates
                #location = geolocator2.geocode(row['Coordinaten'])
                coordinates = [location.latitude, location.longitude]
                accuracy = 1
                print('Row', index+2, ': coordinates provided as string: "', row['Coordinaten'], '". Location:', location)
                Q += 1
        elif (location := geolocator.geocode(f"{row['Land']}, {row['Regio']}, {row['District']}, {row['Locatie']}")):
            # If coordinates are not available, geocode the location
            #location = geolocator.geocode(f"{row['Land']}, {row['Regio']}, {row['District']}, {row['Locatie']}")
            coordinates = [location.latitude, location.longitude]
            if f"{row['Regio']}, {row['District']}, {row['Locatie']}" == '-, -, -': accuracy = 7
            elif f"{row['District']}, {row['Locatie']}" == '-, -': accuracy = 4
            elif f"{row['Locatie']}" == '-': accuracy = 3
            else: accuracy = 2
            print('Row', index+2, ': geocode attempt 1: Land, Regio, District, Locatie.\nAccuracy:', accuracy,' \n    Location provided:',f"{row['Land']}, {row['Regio']}, {row['District']}, {row['Locatie']}" ,'\n    Location calculated:', location)
            Q += 1
        elif (location := geolocator.geocode(f"{row['Land']}, {row['Regio']}, {row['District']}, -")):
            # If geocode does not work, try different data combination 1: District
            #location = geolocator.geocode(f"{row['Land']}, {row['Regio']}, {row['District']}, -")
            coordinates = [location.latitude, location.longitude]
            accuracy = 3
            print('Row', index+2, ': geocode attempt 2: Land, Regio, District. \n    Location provided:',f"{row['Land']}, {row['Regio']}, {row['District']}" ,'\n    Location calculated:', location)
            Q += 1
        elif (location := geolocator.geocode(f"{row['Land']}, {row['Regio']}, -, -")):
            # If geocode does not work, try different data combination 2: Region
            #location = geolocator.geocode(f"{row['Land']}, {row['Regio']}, -, -")
            coordinates = [location.latitude, location.longitude]
            accuracy = 4
            print('Row', index+2, ': geocode attempt 3: Land, Regio. \n    Location provided:',f"{row['Land']}, {row['Regio']}" ,'\n    Location calculated:', location)
            Q += 1
        elif (location := geolocator.geocode(f"{row['LOCALITYTEXT']}")):
            # If geocode does not work, try different data combination 3: LOCALITYTEXT
            #location = geolocator.geocode(f"{row['LOCALITYTEXT']}")
            coordinates = [location.latitude, location.longitude]
            accuracy = 5
            print('Row', index+2, ': geocode attempt 4: LOCALITYTEXT. \n    Location provided:',f"{row['LOCALITYTEXT']}" ,'\n    Location calculated:', location)
            Q += 1
        elif (location := geolocator.geocode(f"{row['LOCALITY']}")): 
            # If geocode does not work, try different data combination 4: LOCALITY
            #location = geolocator.geocode(f"{row['LOCALITY']}")
            coordinates = [location.latitude, location.longitude]
            accuracy = 6
            print('Row', index+2, ': geocode attempt 5: LOCALITY. \n    Location provided:',f"{row['LOCALITY']}" ,'\n    Location calculated:', location)
            Q += 1
        elif (location := geolocator.geocode(f"{row['Land']}, -, -, -")):
            # If geocode does not work, try different data combination 5: Land
            #location = geolocator.geocode(f"{row['Land']}, -, -, -")
            coordinates = [location.latitude, location.longitude]
            accuracy = 7
            print('Row', index+2, ': geocode attempt 6: Land. \n    Location provided:',f"{row['COUNTRY']}" ,'\n    Location calculated:', location)
            Q += 1
        elif (location := row['COUNTRY'] == "Czechoslovakia"):
            # If geocode does not work, and Country = Czeckoslovakia
            #location = 'Czechoslovakia'
            coordinates = [49.115334, 18.109488]
            accuracy = 8
            print('Row', index+2, ': geocode attempt 7 unsuccessful: Country = "Czechoslovakia". \n    Location provided:',f"{row['COUNTRY']}" ,'\n    Location calculated:', location)
            Q += 1
        elif row['COUNTRY'] == "Unknown":
            # If geocode does not work, and Country = Unknown
            location = 'Unknown'
            coordinates = []
            accuracy = 9
            print('Row', index+2, ': geocode attempt 7 unsuccessful: Country = "Unknown". \n    Location provided:',f"{row['COUNTRY']}" ,'\n    Location calculated:', location)
        elif (location := geolocator.geocode(f"{row['COUNTRY']}, {row['Regio']}, {row['District']}, {row['Locatie']}")):
            # If geocode does not work and Country != Chechoslovakia or unknown, try different data combination 6: Country
            #location = geolocator.geocode(f"{row['COUNTRY']}, {row['Regio']}, {row['District']}, {row['Locatie']}")
            coordinates = [location.latitude, location.longitude]
            accuracy = 10
            print('Row', index+2, ': geocode attempt 7: Country. \n    Location provided:',f"{row['COUNTRY']}" ,'\n    Location calculated:', location)
            Q += 1
        else:
            # If last geocode option fails, enter location = unknown
            location = 'Unknown'
            coordinates = []
            accuracy = 11
            print('Row', index+2, ': geocode unsuccessful. \n    Location provided:',f"{row['COUNTRY']}, {row['Regio']}, {row['District']}, {row['Locatie']}, {row['LOCALITYTEXT']}, {row['LOCALITY']}" ,'\n    Location calculated:', location)
        
        #checking certain accuracies
        if location == geolocator.geocode('Czechia'):
            accuracy = 12
            print('Row', index+2, ': location=Czechia -> accuracy=12 \n    Location provided:',f"{row['COUNTRY']}, {row['Regio']}, {row['District']}, {row['Locatie']}, {row['LOCALITYTEXT']}, {row['LOCALITY']}" ,'\n    Location calculated:', location)
            Q += 1
        if location == geolocator.geocode('Slovakia') or location == 'Slovakia': #not working?
            accuracy = 13
            print('Row', index+2, ': location=Slovakia -> accuracy=13 \n    Location provided:',f"{row['COUNTRY']}, {row['Regio']}, {row['District']}, {row['Locatie']}, {row['LOCALITYTEXT']}, {row['LOCALITY']}" ,'\n    Location calculated:', location)
            Q += 1
        
        # Saving data in reorganised dataframe 
        CollectionData_CzechRepublic_Reorganised.loc[index] = {'RegistrationNumber':row['REGISTRATIONNUMBER'],'Description':row['FULLSCIENTIFICNAME'],'Coordinates':coordinates,'Location':location, 'Accuracy':accuracy}
        
        #time.sleep(0.1)
# Out:
# Row 2 : coordinates provided. Location: 402, 588 33 Stonařov, Czechia
# Row 3 : geocode attempt 7 unsuccessful: Country = "Czechoslovakia".
#     Location provided: Czechoslovakia
#     Location calculated: Czechoslovakia
# Row 4 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 5 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Bílina
#     Location calculated: 418 01 Bílina-Bílina 1, Czechia
# Row 6 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 7 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Cínovec
#     Location calculated: Cínovec, 415 01 Dubí-Teplice 1, Czechia
# Row 8 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Olomouc, Šumperk, Sobotín
#     Location calculated: 788 16 Sobotín-Petrov nad Desnou, Czechia
# Row 9 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Děčín, Těchlovice
#     Location calculated: 405 02 Těchlovice-Děčín 2, Czechia
# Row 10 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Ústí nad Labem, Povrly
#     Location calculated: Povrly, Czechia
# Row 11 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Central Bohemian, Kutná Hora, Poličany
#     Location calculated: Poličany, 284 01 Kutná Hora-Kutná Hora 1, Czechia
# Row 12 : coordinates provided. Location: Hlavní tř. 258, 353 01 Mariánské Lázně-Mariánské Lázně 1, Czechia
# Row 13 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Bílina
#     Location calculated: 418 01 Bílina-Bílina 1, Czechia
# Row 14 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 7
#     Location provided: Czech Republic, -, -, -
#     Location calculated: Czechia
# Row 14 : location=Czechia -> accuracy=12
#     Location provided: Czech Republic, -, -, -, Bohemen, Tsjechoslowakije, -
#     Location calculated: Czechia
# Row 15 : geocode attempt 7: Country.
#     Location provided: Czech Republic
#     Location calculated: Czechia
# Row 15 : location=Czechia -> accuracy=12
#     Location provided: Czech Republic, -, -, -, Tsjechoslowakije, -
#     Location calculated: Czechia
# Row 16 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 7
#     Location provided: Czech Republic, -, -, -
#     Location calculated: Czechia
# Row 16 : location=Czechia -> accuracy=12
#     Location provided: Slovakia, -, -, -, MoraviÃ«, MÃ¤hren, Slowakije, -
#     Location calculated: Czechia
# Row 17 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 7
#     Location provided: Czech Republic, -, -, -
#     Location calculated: Czechia
# Row 17 : location=Czechia -> accuracy=12
#     Location provided: Slovakia, -, -, -, MoraviÃ«, Slowakije, -
#     Location calculated: Czechia
# Row 18 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 7
#     Location provided: Czech Republic, -, -, -
#     Location calculated: Czechia
# Row 18 : location=Czechia -> accuracy=12
#     Location provided: Slovakia, -, -, -, MoraviÃ«, MÃ¤hren, Slowakije, -
#     Location calculated: Czechia
# Row 19 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Bílina
#     Location calculated: 418 01 Bílina-Bílina 1, Czechia
# Row 20 : coordinates provided. Location: Hlineč 12/12, Hlineč, 364 71 Bochov, Czechia
# Row 21 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Ústí nad Labem, Homole u Panny, -
#     Location calculated: 403 22 Homole u Panny-Ústí nad Labem 20, Czechia
# Row 22 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 7
#     Location provided: Czech Republic, -, -, -
#     Location calculated: Czechia
# Row 22 : location=Czechia -> accuracy=12
#     Location provided: Czech Republic, -, -, -, Bohemen, TsjechiÃ«, -
#     Location calculated: Czechia
# Row 23 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Ústí nad Labem, Roztoky
#     Location calculated: Ústí nad Labem, Czechia
# Row 24 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 4
#     Location provided: Czech Republic, Ústí nad Labem, -, -
#     Location calculated: Ústí nad Labem, Czechia
# Row 25 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 26 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 27 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 28 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Bílina
#     Location calculated: 418 01 Bílina-Bílina 1, Czechia
# Row 29 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Olomouc, Šumperk, Sobotín
#     Location calculated: 788 16 Sobotín-Petrov nad Desnou, Czechia
# Row 30 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Měrunice
#     Location calculated: 418 04 Měrunice-Bílina 4, Czechia
# Row 31 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Duchcov
#     Location calculated: 419 01 Duchcov, Czechia
# Row 32 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Duchcov
#     Location calculated: 419 01 Duchcov, Czechia
# Row 33 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, South Moravian, Brno, Zastávka
#     Location calculated: 664 84 Zastávka-Zastávka u Brna, Czechia
# Row 34 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Duchcov
#     Location calculated: 419 01 Duchcov, Czechia
# Row 35 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 7
#     Location provided: Czech Republic, -, -, -
#     Location calculated: Czechia
# Row 35 : location=Czechia -> accuracy=12
#     Location provided: Czechoslovakia, -, -, -, Bohemen, Tsjechoslowakije, -
#     Location calculated: Czechia
# Row 36 : geocode attempt 4: LOCALITYTEXT.
#     Location provided: Freiberg (Slow.), Tsjechoslowakije, Slowakije
#     Location calculated: Slovakia
# Row 37 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Cheb, Hazlov
#     Location calculated: Hazlov, Czechia
# Row 38 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Krásno
#     Location calculated: 357 31 Krásno-Horní Slavkov, Czechia
# Row 39 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 40 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Krásno
#     Location calculated: 357 31 Krásno-Horní Slavkov, Czechia
# Row 41 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Olomouc, Jeseník, Žulová
#     Location calculated: 790 65 Žulová, Czechia
# Row 42 : coordinates provided. Location: Silnice bez názvu, 788 11 Loučná nad Desnou, Czechia
# Row 43 : coordinates provided. Location: Silnice bez názvu, 788 11 Loučná nad Desnou, Czechia
# Row 44 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, South Bohemian, Písek, -
#     Location calculated: 397 01 Pisek-Písek 1, Czechia
# Row 45 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Cínovec
#     Location calculated: Cínovec, 415 01 Dubí-Teplice 1, Czechia
# Row 46 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 47 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Krásno
#     Location calculated: 357 31 Krásno-Horní Slavkov, Czechia
# Row 48 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Krásno
#     Location calculated: 357 31 Krásno-Horní Slavkov, Czechia
# Row 49 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Krásno
#     Location calculated: 357 31 Krásno-Horní Slavkov, Czechia
# Row 50 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Liberec, Semily, Košťálov
#     Location calculated: Košťálov, Czechia
# Row 51 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Moravian-Silesian, Opava, -
#     Location calculated: Opava, Czechia
# Row 52 : coordinates provided. Location: Silnice bez názvu, 788 11 Loučná nad Desnou, Czechia
# Row 53 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Cínovec
#     Location calculated: Cínovec, 415 01 Dubí-Teplice 1, Czechia
# Row 54 : coordinates provided. Location: 8, 415 01 Bořislav-Teplice 1, Czechia
# Row 55 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Vysočina, Žďár nad Sázavou, Dolní Bory
#     Location calculated: Dolní Bory, 594 61 Bory, Czechia
# Row 56 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Vysočina, Žďár nad Sázavou, Heřmanov
#     Location calculated: 594 51 Heřmanov-Křižanov, Czechia
# Row 57 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Vysočina, Žďár nad Sázavou, Heřmanov
#     Location calculated: 594 51 Heřmanov-Křižanov, Czechia
# Row 58 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 4
#     Location provided: Czech Republic, Karlovy Vary, -, -
#     Location calculated: Karlovy Vary, Czechia
# Row 59 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Bílina
#     Location calculated: 418 01 Bílina-Bílina 1, Czechia
# Row 60 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Želénky
#     Location calculated: Želénky, 417 71 Zabrušany, Czechia
# Row 61 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Karlovy Vary, Černava
#     Location calculated: 362 21 Černava-Nejdek 1, Czechia
# Row 62 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 4
#     Location provided: Czech Republic, Karlovy Vary, -, -
#     Location calculated: Karlovy Vary, Czechia
# Row 63 : coordinates provided. Location: U Červené lávky 569, 349 01 Stříbro, Czechia
# Row 64 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 65 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 4
#     Location provided: Czech Republic, Karlovy Vary, -, -
#     Location calculated: Karlovy Vary, Czechia
# Row 66 : coordinates provided. Location: Silnice I/15, 440 01 Libčeves-Louny 1, Czechia
# Row 67 : coordinates provided. Location: Silnice I/15, 440 01 Libčeves-Louny 1, Czechia
# Row 68 : coordinates provided. Location: Silnice I/15, 440 01 Libčeves-Louny 1, Czechia
# Row 69 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Bílina
#     Location calculated: 418 01 Bílina-Bílina 1, Czechia
# Row 70 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Bílina
#     Location calculated: 418 01 Bílina-Bílina 1, Czechia
# Row 71 : coordinates provided. Location: U Červené lávky 569, 349 01 Stříbro, Czechia
# Row 72 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, -
#     Location calculated: Teplice, Czechia
# Row 73 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Chomutov, Loučná pod Klínovcem
#     Location calculated: 431 91 Loučná pod Klínovcem-Vejprty, Czechia
# Row 74 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, South Bohemian, Písek, -
#     Location calculated: 397 01 Pisek-Písek 1, Czechia
# Row 75 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Bořislav
#     Location calculated: 415 01 Bořislav-Teplice 1, Czechia
# Row 76 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, South Bohemian, Písek, -
#     Location calculated: 397 01 Pisek-Písek 1, Czechia
# Row 77 : coordinates provided. Location: Silnice bez názvu, 262 23 Brdy-Jince, Czechia
# Row 78 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 79 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Karlovy Vary, -
#     Location calculated: Karlovy Vary, Czechia
# Row 80 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Osek
#     Location calculated: Osek, Czechia
# Row 81 : geocode attempt 7 unsuccessful: Country = "Czechoslovakia".
#     Location provided: Czechoslovakia
#     Location calculated: Czechoslovakia
# Row 82 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Cheb, Aš
#     Location calculated: 352 01 Aš-Aš 1, Czechia
# Row 83 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, -, Velké Březno
#     Location calculated: Velké Březno, Czechia
# Row 84 : coordinates provided. Location: Hlavní tř. 258, 353 01 Mariánské Lázně-Mariánské Lázně 1, Czechia
# Row 85 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Central Bohemian, Příbram, Bohutín
#     Location calculated: 262 41 Bohutín, Czechia
# Row 86 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 87 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 88 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 89 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 90 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 91 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 92 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 93 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 94 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 95 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 96 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 97 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 98 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 99 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 100 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 101 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 102 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 103 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 104 : coordinates provided. Location: Lánský dvůr 840, 357 31 Horní Slavkov, Czechia
# Row 105 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 106 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 107 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 108 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 109 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 110 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 111 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 112 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 113 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 114 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 115 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 116 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 117 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 118 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 119 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 120 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 121 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 122 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 123 : coordinates provided. Location: Lánský dvůr 840, 357 31 Horní Slavkov, Czechia
# Row 124 : coordinates provided. Location: Lánský dvůr 840, 357 31 Horní Slavkov, Czechia
# Row 125 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 126 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 127 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 128 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 129 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 130 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 131 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 132 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 133 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 134 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 135 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 136 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 137 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 138 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 139 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 140 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 141 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 142 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 143 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 144 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 145 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 146 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 147 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 148 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 149 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 150 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 151 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 152 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 153 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 154 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 155 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 156 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 157 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 158 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 159 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 160 : coordinates provided. Location: Lánský dvůr 840, 357 31 Horní Slavkov, Czechia
# Row 161 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 162 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 163 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 164 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 165 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 166 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 167 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 168 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 169 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 170 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 171 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 172 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 173 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 174 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 175 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 176 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 177 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 178 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 179 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 180 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 181 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 182 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 183 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 184 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 185 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 186 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 187 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 188 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 189 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 190 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 191 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 192 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 193 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 194 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 195 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 196 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 197 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 198 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 199 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 200 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 201 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 202 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 203 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 204 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 205 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 206 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 207 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 208 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 209 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 210 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 211 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 212 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 213 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 214 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 215 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 216 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 217 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 218 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 219 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 220 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 221 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 222 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 223 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 224 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 225 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 226 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 227 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 228 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 229 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 230 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 231 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 232 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 233 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 234 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 235 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 236 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 237 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 238 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 239 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 240 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 241 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 242 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 243 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 244 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 245 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 246 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# ...
# Row 1381 : coordinates provided. Location: Husova 270, Březové Hory, 261 01 Příbram-Příbram 1, Czechia
# Row 1382 : coordinates provided. Location: Husova 270, Březové Hory, 261 01 Příbram-Příbram 1, Czechia
# Row 1383 : coordinates provided. Location: Roudný 1, 257 06 Zvěstov-Louňovice pod Blaníkem, Czechia
# Row 1384 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Košice, Spišská Nová Ves, Rudňany
#     Location calculated: 053 23 Rudňany, Slovakia
# Row 1385 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Košice, Spišská Nová Ves, Rudňany
#     Location calculated: 053 23 Rudňany, Slovakia
# Row 1386 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Košice, Spišská Nová Ves, Rudňany
#     Location calculated: 053 23 Rudňany, Slovakia
# Row 1387 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Košice, Spišská Nová Ves, Rudňany
#     Location calculated: 053 23 Rudňany, Slovakia
# Row 1388 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Vysočina, Žďár nad Sázavou, Dolní Bory
#     Location calculated: Dolní Bory, 594 61 Bory, Czechia
# Row 1389 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Olomouc, Šumperk, Vernířovice
#     Location calculated: 788 15 Vernířovice-Velké Losiny, Czechia
# Row 1390 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Cínovec
#     Location calculated: Cínovec, 415 01 Dubí-Teplice 1, Czechia
# Row 1391 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Cínovec
#     Location calculated: Cínovec, 415 01 Dubí-Teplice 1, Czechia
# Row 1392 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 1393 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 7
#     Location provided: Czech Republic, -, -, -
#     Location calculated: Czechia
# Row 1393 : location=Czechia -> accuracy=12
#     Location provided: TsjechiÃ«, -, -, -, Czechoslovakia, MoraviÃ«, Klein Wien, Klein Wien
#     Location calculated: Czechia
# Row 1394 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 1395 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 1396 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Cínovec
#     Location calculated: Cínovec, 415 01 Dubí-Teplice 1, Czechia
# Row 1397 : coordinates provided. Location: U Červené lávky 569, 349 01 Stříbro, Czechia
# Row 1398 : coordinates provided. Location: Němčice 181, 533 52 Němčice, Czechia
# Row 1399 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1400 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Cínovec
#     Location calculated: Cínovec, 415 01 Dubí-Teplice 1, Czechia
# Row 1401 : coordinates provided. Location: Třenická hora 500m.n.m, 2353, 267 61 Cerhovice, Czechia
# Row 1402 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, -, Dolni Zálezly
#     Location calculated: Dolní Zálezly, Czechia
# Row 1403 : coordinates provided. Location: U Červené lávky 569, 349 01 Stříbro, Czechia
# Row 1404 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 1405 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 1406 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1407 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1408 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Košice, Spišská Nová Ves, Rudňany
#     Location calculated: 053 23 Rudňany, Slovakia
# Row 1409 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Horní Blatná, Horní Blatná (m)
#     Location calculated: Horní Blatná, Czechia
# Row 1410 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Krupka
#     Location calculated: Krupka, Czechia
# Row 1411 : coordinates provided. Location: Silnice bez názvu, 353 01 Ovesné Kladruby-Mariánské Lázně 1, Czechia
# Row 1412 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1413 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1414 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1415 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1416 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1417 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1418 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1419 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Plzeň, Domažlice, Poběžovice
#     Location calculated: 345 22 Poběžovice, Czechia
# Row 1420 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1421 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1422 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 7
#     Location provided: Czech Republic, -, -, -
#     Location calculated: Czechia
# Row 1422 : location=Czechia -> accuracy=12
#     Location provided: -, -, -, -, Bohemen, Tsjechoslowakije, Pribram
#     Location calculated: Czechia
# Row 1423 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Olomouc, Jeseník, Žulová
#     Location calculated: 790 65 Žulová, Czechia
# Row 1424 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 7
#     Location provided: Czech Republic, -, -, -
#     Location calculated: Czechia
# Row 1424 : location=Czechia -> accuracy=12
#     Location provided: TsjechiÃ«, -, -, -, Bohemen, Tsjechoslowakije, Pisek, Pisek
#     Location calculated: Czechia
# Row 1425 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 7
#     Location provided: Czech Republic, -, -, -
#     Location calculated: Czechia
# Row 1425 : location=Czechia -> accuracy=12
#     Location provided: TsjechiÃ«, -, -, -, Bohemen, Tsjechoslowakije, Haslau, Haslau
#     Location calculated: Czechia
# Row 1426 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Plzeň, Domažlice, Poběžovice
#     Location calculated: 345 22 Poběžovice, Czechia
# Row 1427 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Želénky
#     Location calculated: Želénky, 417 71 Zabrušany, Czechia
# Row 1428 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Cínovec
#     Location calculated: Cínovec, 415 01 Dubí-Teplice 1, Czechia
# Row 1429 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 7
#     Location provided: Czech Republic, -, -, -
#     Location calculated: Czechia
# Row 1429 : location=Czechia -> accuracy=12
#     Location provided: TsjechiÃ«, -, -, -, Tilln, Bohemen, Tsjechoslowakije, Tilln,
#     Location calculated: Czechia
# Row 1430 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Vysočina, Žďár nad Sázavou, Dolní Libochová
#     Location calculated: 592 53 Dolní Libochová-Strážek, Czechia
# Row 1431 : coordinates provided. Location: Karlovotýnská 121, 252 16 Nučice, Czechia
# Row 1432 : coordinates provided. Location: Třenická hora 500m.n.m, 2353, 267 61 Cerhovice, Czechia
# Row 1433 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 1434 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 7
#     Location provided: Czech Republic, -, -, -
#     Location calculated: Czechia
# Row 1434 : location=Czechia -> accuracy=12
#     Location provided: TsjechiÃ«, -, -, -, Vinik, Bohemen, Tsjechoslowakije, Vinik
#     Location calculated: Czechia
# Row 1435 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 1436 : coordinates provided. Location: Třenická hora 500m.n.m, 2353, 267 61 Cerhovice, Czechia
# Row 1437 : coordinates provided. Location: U Červené lávky 569, 349 01 Stříbro, Czechia
# Row 1438 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 1439 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Ústí nad Labem, Teplice, Duchcov
#     Location calculated: 419 01 Duchcov, Czechia
# Row 1440 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Central Bohemian, Příbram, Krásná Hora nad Vltavou
#     Location calculated: 262 56 Krásná Hora nad Vltavou, Czechia
# Row 1441 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Central Bohemian, Příbram, Krásná Hora nad Vltavou
#     Location calculated: 262 56 Krásná Hora nad Vltavou, Czechia
# Row 1442 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Olomouc, Šumperk, Branná
#     Location calculated: 788 25 Branná-Výdejní místo Branná, Czechia
# Row 1443 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Liberec, Česká Lípa, Okrouhlá
#     Location calculated: 473 01 Okrouhlá-Nový Bor, Czechia
# Row 1444 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Liberec, Česká Lípa, Okrouhlá
#     Location calculated: 473 01 Okrouhlá-Nový Bor, Czechia
# Row 1445 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1446 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 1447 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Karlovy Vary, Jáchymov, -
#     Location calculated: Jáchymov, Czechia
# Row 1448 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1449 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Central Bohemian, Příbram, Černojamské
#     Location calculated: Příbram, Czechia
# Row 1450 : coordinates provided. Location: Obecnická 269, Březové Hory, 261 01 Příbram-Příbram 1, Czechia
# Row 1451 : coordinates provided. Location: Vysoká Pec 47, 262 41 Bohutín, Czechia
# Row 1452 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Central Bohemian, Příbram, Bohutín
#     Location calculated: 262 41 Bohutín, Czechia
# Row 1453 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Central Bohemian, Příbram, Jílové rozsedliny (Lettenkluft)
#     Location calculated: 254 01 Jílové u Prahy, Czechia
# Row 1454 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Central Bohemian, Příbram, Jílové rozsedliny (Lettenkluft)
#     Location calculated: 254 01 Jílové u Prahy, Czechia
# Row 1455 : coordinates provided. Location: Vysoká Pec 47, 262 41 Bohutín, Czechia
# Row 1456 : coordinates provided. Location: Kozičín 25, 261 01 Příbram-Příbram 1, Czechia
# Row 1457 : coordinates provided. Location: Husova 270, Březové Hory, 261 01 Příbram-Příbram 1, Czechia
# Row 1458 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1459 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1460 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1461 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1462 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 3
#     Location provided: Czech Republic, Central Bohemian, Příbram, -
#     Location calculated: Příbram, Czechia
# Row 1463 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Sokolov, Horní Slavkov
#     Location calculated: 357 31 Horní Slavkov, Czechia
# Row 1464 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Liberec, Semily, Jilemnice
#     Location calculated: 514 01 Jilemnice, Czechia
# Row 1465 : geocode attempt 1: Land, Regio, District, Locatie.
# Accuracy: 2
#     Location provided: Czech Republic, Karlovy Vary, Karlovy Vary, Černava
#     Location calculated: 362 21 Černava-Nejdek 1, Czechia
# Row 1466 : coordinates provided. Location: Třemošenská 292, Březové Hory, 261 01 Příbram-Příbram 1, Czechia

# %%
# Part of script for plotting reorganised data

import pandas as pd
import geopandas as gpd
import folium
from folium.plugins import MarkerCluster
from geopy.geocoders import Nominatim
from geopy.geocoders import GoogleV3


#print(CollectionData_CzechRepublic_Reorganised)

# Create a map centered around a specific location
center = geolocator.geocode('Czech Republic')
center_coordinates = [center.latitude, center.longitude]
mymap = folium.Map(location=center_coordinates, zoom_start=7)

# Create a MarkerCluster layer
marker_cluster_CzechRepublic = MarkerCluster(max_cluster_radius=25)

for index, row in CollectionData_CzechRepublic_Reorganised.iterrows():
    
    if index>10000: break
    else:
        
        # Add marker to the map with different colors indicating precision
        if row['Accuracy'] == 0 or row['Accuracy'] == 1:
            # Most specific location known (coordinates)
            popup = f"{row['RegistrationNumber']}, {row['Description']},\n{row['Location']},\n{row['Coordinates']}"
            folium.CircleMarker(location=row['Coordinates'], radius=5, color='blue', fill=True, popup=popup).add_to(marker_cluster_CzechRepublic)
        elif row['Accuracy'] == 2:
            # Location is the most specific location known
            popup = f"{row['RegistrationNumber']}, {row['Description']},\n{row['Location']}"
            folium.CircleMarker(location=row['Coordinates'], radius=5, color='green', fill=True, popup=popup).add_to(marker_cluster_CzechRepublic)
        elif row['Accuracy'] == 3:
            # District is the most specific location known
            popup = f"{row['RegistrationNumber']}, {row['Description']},\n{row['Location']}"
            folium.CircleMarker(location=row['Coordinates'], radius=5, color='yellowgreen', fill=True, popup=popup).add_to(marker_cluster_CzechRepublic)
        elif row['Accuracy'] == 4:
            # Region is the most specific location known
            popup = f"{row['RegistrationNumber']}, {row['Description']},\n{row['Location']}"
            folium.CircleMarker(location=row['Coordinates'], radius=5, color='orange', fill=True, popup=popup).add_to(marker_cluster_CzechRepublic)
        elif row['Accuracy'] == 7 or row['Accuracy'] == 8 or row['Accuracy'] == 10 or row['Accuracy'] == 12 or row['Accuracy'] == 13 or row['Accuracy'] == 5:
            # Country is the most specific location known
            popup = f"{row['RegistrationNumber']}, {row['Description']},\n{row['Location']}"
            folium.CircleMarker(location=row['Coordinates'], radius=5, color='red', fill=True, popup=popup).add_to(marker_cluster_CzechRepublic)      
        elif row['Accuracy'] == 5 or row['Accuracy'] == 6:
            # LOCALITY(TEXT) is the most specific location known and might be inaccurate
            print('Row', index+2, ': ', row['Location'])
            print(row['Accuracy'])
            popup = f"{row['RegistrationNumber']}, {row['Description']},\n{row['Location']}"
            folium.CircleMarker(location=row['Coordinates'], radius=5, color='purple', fill=True, popup=popup).add_to(marker_cluster_CzechRepublic)      
#        elif row['Accuracy'] == (9 or row['Accuracy'] == 11):
#            # Location is unknown
#            folium.CircleMarker(location="Amsterdam, Nederland", radius=5, color=(0, 0, 0), fill=True).add_to(marker_cluster_CzechRepublic)      
        
            
# Add the marker cluster to the map
marker_cluster_CzechRepublic.add_to(mymap)

custom_css = """
    /* Custom CSS styles to increase the size of marker clusters by 50% and make markers opaque */
    .leaflet-marker-icon.marker-cluster {
        width: 0px !important;  /* Increase cluster width by 50% */
        height: 0px !important;  /* Increase cluster height by 50% */
    }
    
"""

# Add custom CSS styles to the map
mymap.get_root().header.add_child(folium.Element("<style>{}</style>".format(custom_css)))

# Create a legend
legend_html = """
<div style="position: fixed; 
             bottom: 10px; left: 10px; width: 150px; height: 202px; 
             border:3px solid grey; z-index:9999; font-size:14px;
             background-color: white;
             ">
    <p><strong>Precisie van locatie</strong></p>
    <svg width="20" height="20">
        <circle cx="10" cy="10" r="5" fill="none" stroke="blue" stroke-width="4" />    
    </svg>
    <span>Coördinaten</span><br>
    <svg width="20" height="20">
        <circle cx="10" cy="10" r="5" fill="none" stroke="green" stroke-width="4" />  
    </svg>
    <span>Locatie</span><br>
        <svg width="20" height="20">
        <circle cx="10" cy="10" r="5" fill="none" stroke="yellowgreen" stroke-width="4" />  
    </svg>
    <span>Regio</span><br>
        <svg width="20" height="20">
        <circle cx="10" cy="10" r="5" fill="none" stroke="orange" stroke-width="4" />  
    </svg>
    <span>District</span><br>
        <svg width="20" height="20">
        <circle cx="10" cy="10" r="5" fill="none" stroke="red" stroke-width="4" />  
    </svg>
    <span>Land</span><br>
    <p><small>*Kleur van clusters geeft clustergrootte aan ipv. precisie.<small></p>
</div>
"""

# Add the legend as an additional layer
legend = branca.element.Element(legend_html)
mymap.get_root().html.add_child(legend)

#folium.CircleMarker(location=[49.115334, 18.109488], radius=50, color='yellow', fill=True).add_to(marker_cluster_CzechRepublic)

# Display the map
mymap
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 14
#       8 from geopy.geocoders import GoogleV3
#      11 #print(CollectionData_CzechRepublic_Reorganised)
#      12
#      13 # Create a map centered around a specific location
# ---> 14 center = geolocator.geocode('Czech Republic')
#      15 center_coordinates = [center.latitude, center.longitude]
#      16 mymap = folium.Map(location=center_coordinates, zoom_start=7)
#
# NameError: name 'geolocator' is not defined

# %%
mymap.save("mineral_map")
#mymap.save("Interactieve kaart mineralencollectie Tsjechië.html")
